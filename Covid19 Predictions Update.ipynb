# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd 
import random
import math
import time
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import datetime
import operator 
plt.style.use('fivethirtyeight')
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
latest_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/11-12-2020.csv')
apple_mobility = pd.read_csv('https://covid19-static.cdn-apple.com/covid19-mobility-data/2021HotfixDev9/v3/en-us/applemobilitytrends-2020-11-12.csv')

# %%
latest_data.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2020-11-13 05:25:30  33.93911
# 1   NaN    NaN            NaN        Albania  2020-11-13 05:25:30  41.15330
# 2   NaN    NaN            NaN        Algeria  2020-11-13 05:25:30  28.03390
# 3   NaN    NaN            NaN        Andorra  2020-11-13 05:25:30  42.50630
# 4   NaN    NaN            NaN         Angola  2020-11-13 05:25:30 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953      42795    1591      35024   6180.0  Afghanistan
# 1  20.168300      26211     598      12574  13039.0      Albania
# 2   1.659600      65108    2111      42980  20017.0      Algeria
# 3   1.521800       5616      75       4585    956.0      Andorra
# 4  17.873900      13053     315       6250   6488.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     109.932761             3.717724
# 1     910.799917             2.281485
# 2     148.475374             3.242305
# 3    7268.491555             1.335470
# 4      39.715492             2.413238

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  11/9/20  11/10/20  11/11/20  \
# 0        0        0        0        0  ...    42297     42463     42609
# 1        0        0        0        0  ...    24731     25294     25801
# 2        0        0        0        0  ...    62693     63446     64257
# 3        0        0        0        0  ...     5437      5477      5567
# 4        0        0        0        0  ...    12680     12816     12953
#
#    11/12/20  11/13/20  11/14/20  11/15/20  11/16/20  11/17/20  11/18/20
# 0     42795     42969     43035     43240     43403     43628     43851
# 1     26211     26701     27233     27830     28432     29126     29837
# 2     65108     65975     66819     67679     68589     69591     70629
# 3      5616      5725      5725      5872      5914      5951      6018
# 4     13053     13228     13374     13451     13615     13818     13922
#
# [5 rows x 306 columns]

# %%
cols = confirmed_df.keys()

# %%
confirmed = confirmed_df.loc[:, cols[4]:cols[-1]]
deaths = deaths_df.loc[:, cols[4]:cols[-1]]
recoveries = recoveries_df.loc[:, cols[4]:cols[-1]]

# %%
dates = confirmed.keys()
world_cases = []
total_deaths = [] 
mortality_rate = []
recovery_rate = [] 
total_recovered = [] 
total_active = [] 
turkey_cases = []

for i in dates:
    confirmed_sum = confirmed[i].sum()
    death_sum = deaths[i].sum()
    recovered_sum = recoveries[i].sum()
    
    # confirmed, deaths, recovered, and active
    world_cases.append(confirmed_sum)
    total_deaths.append(death_sum)
    total_recovered.append(recovered_sum)
    total_active.append(confirmed_sum-death_sum-recovered_sum)
    
    # calculate rates
    mortality_rate.append(death_sum/confirmed_sum)
    recovery_rate.append(recovered_sum/confirmed_sum)
    
    turkey_cases.append(confirmed_df[confirmed_df['Country/Region']=='Turkey'][i].sum())

# %%
def daily_increase(data):
    d = [] 
    for i in range(len(data)):
        if i == 0:
            d.append(data[0])
        else:
            d.append(data[i]-data[i-1])
    return d 

def moving_average(data, window_size):
    moving_average = []
    for i in range(len(data)):
        if i + window_size < len(data):
            moving_average.append(np.mean(data[i:i+window_size]))
        else:
            moving_average.append(np.mean(data[i:len(data)]))
    return moving_average

# window size
window = 7

# confirmed cases
world_daily_increase = daily_increase(world_cases)
world_confirmed_avg= moving_average(world_cases, window)
world_daily_increase_avg = moving_average(world_daily_increase, window)
turkey_daily_increase = daily_increase(turkey_cases)
turkey_confirmed_avg= moving_average(turkey_cases, window)
turkey_daily_increase_avg = moving_average(turkey_daily_increase, window)

# deaths
world_daily_death = daily_increase(total_deaths)
world_death_avg = moving_average(total_deaths, window)
world_daily_death_avg = moving_average(world_daily_death, window)



# recoveries
world_daily_recovery = daily_increase(total_recovered)
world_recovery_avg = moving_average(total_recovered, window)
world_daily_recovery_avg = moving_average(world_daily_recovery, window)


# active 
world_active_avg = moving_average(total_active, window)

# %%
days_since_1_22 = np.array([i for i in range(len(dates))]).reshape(-1, 1)
world_cases = np.array(world_cases).reshape(-1, 1)
total_deaths = np.array(total_deaths).reshape(-1, 1)
total_recovered = np.array(total_recovered).reshape(-1, 1)
turkey_cases = np.array(turkey_cases).reshape(-1, 1)

# %%
days_in_future = 10
future_forcast = np.array([i for i in range(len(dates)+days_in_future)]).reshape(-1, 1)
adjusted_dates = future_forcast[:-10]

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start, '%m/%d/%Y')
future_forcast_dates = []
for i in range(len(future_forcast)):
    future_forcast_dates.append((start_date + datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
def flatten(arr):
    a = [] 
    arr = arr.tolist()
    for i in arr:
        a.append(i[0])
    return a

# %%
adjusted_dates = adjusted_dates.reshape(1, -1)[0]
plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, world_cases)
plt.plot(adjusted_dates, world_confirmed_avg, linestyle='dashed', color='orange')
plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Worldwide Coronavirus Cases', 'Moving Average {} Days'.format(window)], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, total_deaths)
plt.plot(adjusted_dates, world_death_avg, linestyle='dashed', color='orange')
plt.title('# of Coronavirus Deaths Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Worldwide Coronavirus Deaths', 'Moving Average {} Days'.format(window)], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, total_recovered)
plt.plot(adjusted_dates, world_recovery_avg, linestyle='dashed', color='orange')
plt.title('# of Coronavirus Recoveries Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Worldwide Coronavirus Recoveries', 'Moving Average {} Days'.format(window)], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, total_active)
plt.plot(adjusted_dates, world_active_avg, linestyle='dashed', color='orange')
plt.title('# of Coronavirus Active Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Active Cases', size=30)
plt.legend(['Worldwide Coronavirus Active Cases', 'Moving Average {} Days'.format(window)], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.bar(adjusted_dates, world_daily_increase)
plt.plot(adjusted_dates, world_daily_increase_avg, color='red', linestyle='dashed')
plt.title('World Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Moving Average {} Days'.format(window), 'World Daily Increase in COVID-19 Cases'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(adjusted_dates, world_daily_death)
plt.plot(adjusted_dates, world_daily_death_avg, color='red', linestyle='dashed')
plt.title('World Daily Increases in Confirmed Deaths', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Moving Average {} Days'.format(window), 'World Daily Increase in COVID-19 Deaths'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(adjusted_dates, world_daily_recovery)
plt.plot(adjusted_dates, world_daily_recovery_avg, color='red', linestyle='dashed')
plt.title('World Daily Increases in Confirmed Recoveries', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['Moving Average {} Days'.format(window), 'World Daily Increase in COVID-19 Recoveries'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, np.log10(world_cases))
plt.title('Log of # of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, np.log10(total_deaths))
plt.title('Log of # of Coronavirus Deaths Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, np.log10(total_recovered))
plt.title('Log of # of Coronavirus Recoveries Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
def country_plot(x, y1, y2, y3, y4, country):
    # window is set as 14 in in the beginning of the notebook 
    confirmed_avg = moving_average(y1, window)
    confirmed_increase_avg = moving_average(y2, window)
    death_increase_avg = moving_average(y3, window)
    recovery_increase_avg = moving_average(y4, window)
    
    plt.figure(figsize=(16, 10))
    plt.plot(x, y1)
    plt.plot(x, confirmed_avg, color='red', linestyle='dashed')
    plt.legend(['{} Confirmed Cases'.format(country), 'Moving Average {} Days'.format(window)], prop={'size': 20})
    plt.title('{} Confirmed Cases'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

    plt.figure(figsize=(16, 10))
    plt.bar(x, y2)
    plt.plot(x, confirmed_increase_avg, color='red', linestyle='dashed')
    plt.legend(['Moving Average {} Days'.format(window), '{} Daily Increase in Confirmed Cases'.format(country)], prop={'size': 20})
    plt.title('{} Daily Increases in Confirmed Cases'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

    plt.figure(figsize=(16, 10))
    plt.bar(x, y3)
    plt.plot(x, death_increase_avg, color='red', linestyle='dashed')
    plt.legend(['Moving Average {} Days'.format(window), '{} Daily Increase in Confirmed Deaths'.format(country)], prop={'size': 20})
    plt.title('{} Daily Increases in Deaths'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

    plt.figure(figsize=(16, 10))
    plt.bar(x, y4)
    plt.plot(x, recovery_increase_avg, color='red', linestyle='dashed')
    plt.legend(['Moving Average {} Days'.format(window), '{} Daily Increase in Confirmed Recoveries'.format(country)], prop={'size': 20})
    plt.title('{} Daily Increases in Recoveries'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()
      
# helper function for getting country's cases, deaths, and recoveries        
def get_country_info(country_name):
    country_cases = []
    country_deaths = []
    country_recoveries = []  
    
    for i in dates:
        country_cases.append(confirmed_df[confirmed_df['Country/Region']==country_name][i].sum())
        country_deaths.append(deaths_df[deaths_df['Country/Region']==country_name][i].sum())
        country_recoveries.append(recoveries_df[recoveries_df['Country/Region']==country_name][i].sum())
    return (country_cases, country_deaths, country_recoveries)
    
    
def country_visualizations(country_name):
    country_info = get_country_info(country_name)
    country_cases = country_info[0]
    country_deaths = country_info[1]
    country_recoveries = country_info[2]
    
    country_daily_increase = daily_increase(country_cases)
    country_daily_death = daily_increase(country_deaths)
    country_daily_recovery = daily_increase(country_recoveries)
    
    country_plot(adjusted_dates, country_cases, country_daily_increase, country_daily_death, country_daily_recovery, country_name)

# %%
countries = ['Turkey', 'Russia', 'China', 'Italy','Germany', 'Spain', 'France', 'United Kingdom'] 

for country in countries:
    country_visualizations(country)

# %%
# Country Comparison
# removed redundant code

compare_countries = ['China', 'Italy', 'German', 'Turkey'] 
graph_name = ['Coronavirus Confirmed Cases', 'Coronavirus Confirmed Deaths', 'Coronavirus Confirmed Recoveries']

for num in range(3):
    plt.figure(figsize=(16, 10))
    for country in compare_countries:
        plt.plot(get_country_info(country)[num])
    plt.legend(compare_countries, prop={'size': 20})
    plt.xlabel('Days since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.title(graph_name[num], size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

# %%
# slightly modify the data to fit the model better (regression models cannot pick the pattern)
X_train_confirmed, X_test_confirmed, y_train_confirmed, y_test_confirmed = train_test_split(days_since_1_22[50:], world_cases[50:], test_size=0.05, shuffle=False)

# %%
# svm_confirmed = svm_search.best_estimator_
svm_confirmed = SVR(shrinking=True, kernel='poly',gamma=0.01, epsilon=1,degree=3, C=0.1)
svm_confirmed.fit(X_train_confirmed, y_train_confirmed)
svm_pred = svm_confirmed.predict(future_forcast)

# %%
# check against testing data
svm_test_pred = svm_confirmed.predict(X_test_confirmed)
plt.plot(y_test_confirmed)
plt.plot(svm_test_pred)
plt.legend(['Test Data', 'SVM Predictions'])
print('MAE:', mean_absolute_error(svm_test_pred, y_test_confirmed))
print('MSE:',mean_squared_error(svm_test_pred, y_test_confirmed))
# Out:
# MAE: 1393233.276435543
# MSE: 1975874846116.59

# %%
# Future predictions using SVM 
print('SVM future predictions:')
set(zip(future_forcast_dates[-10:], np.round(svm_pred[-10:])))
# Out:
# SVM future predictions:
# {('11/19/2020', 57941951.0),
#  ('11/20/2020', 58502962.0),
#  ('11/21/2020', 59067689.0),
#  ('11/22/2020', 59636144.0),
#  ('11/23/2020', 60208338.0),
#  ('11/24/2020', 60784285.0),
#  ('11/25/2020', 61363995.0),
#  ('11/26/2020', 61947483.0),
#  ('11/27/2020', 62534759.0),
#  ('11/28/2020', 63125836.0)}

# %%
# Future predictions using SVM 
svm_df = pd.DataFrame({'Date': future_forcast_dates[-10:], 'SVM Predicted # of Confirmed Cases Worldwide': np.round(svm_pred[-10:])})
svm_df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_05962d74_2a35_11eb_8f8e_00059a3c7a00row0_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row1_col1{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row2_col1{
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row3_col1{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row4_col1{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row5_col1{
#             background-color:  #f6583e;
#             color:  #000000;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row6_col1{
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row7_col1{
#             background-color:  #c4161c;
#             color:  #f1f1f1;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row8_col1{
#             background-color:  #9f0e14;
#             color:  #f1f1f1;
#         }#T_05962d74_2a35_11eb_8f8e_00059a3c7a00row9_col1{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >SVM Predicted # of Confirmed Cases Worldwide</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row0_col0" class="data row0 col0" >11/19/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row0_col1" class="data row0 col1" >57941951.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row1_col0" class="data row1 col0" >11/20/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row1_col1" class="data row1 col1" >58502962.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row2_col0" class="data row2 col0" >11/21/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row2_col1" class="data row2 col1" >59067689.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row3_col0" class="data row3 col0" >11/22/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row3_col1" class="data row3 col1" >59636144.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row4_col0" class="data row4 col0" >11/23/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row4_col1" class="data row4 col1" >60208338.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row5_col0" class="data row5 col0" >11/24/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row5_col1" class="data row5 col1" >60784285.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row6_col0" class="data row6 col0" >11/25/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row6_col1" class="data row6 col1" >61363995.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row7_col0" class="data row7 col0" >11/26/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row7_col1" class="data row7 col1" >61947483.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row8_col0" class="data row8 col0" >11/27/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row8_col1" class="data row8 col1" >62534759.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row9_col0" class="data row9 col0" >11/28/2020</td>
#                         <td id="T_05962d74_2a35_11eb_8f8e_00059a3c7a00row9_col1" class="data row9 col1" >63125836.000000</td>
#             </tr>
#     </tbody></table>

# %%
# slightly modify the data to fit the model better (regression models cannot pick the pattern)
X_train_confirmed, X_test_confirmed, y_train_confirmed, y_test_confirmed = train_test_split(days_since_1_22[50:], turkey_cases[50:], test_size=0.05, shuffle=False)

# %%
poly = PolynomialFeatures(degree=4)
poly_X_train_confirmed = poly.fit_transform(X_train_confirmed)
poly_X_test_confirmed = poly.fit_transform(X_test_confirmed)
poly_future_forcast = poly.fit_transform(future_forcast)

bayesian_poly = PolynomialFeatures(degree=5)
bayesian_poly_X_train_confirmed = bayesian_poly.fit_transform(X_train_confirmed)
bayesian_poly_X_test_confirmed = bayesian_poly.fit_transform(X_test_confirmed)
bayesian_poly_future_forcast = bayesian_poly.fit_transform(future_forcast)

# %%
# polynomial regression
linear_model = LinearRegression(normalize=True, fit_intercept=False)
linear_model.fit(poly_X_train_confirmed, y_train_confirmed)
test_linear_pred = linear_model.predict(poly_X_test_confirmed)
linear_pred = linear_model.predict(poly_future_forcast)
print('MAE:', mean_absolute_error(test_linear_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_linear_pred, y_test_confirmed))
# Out:
# MAE: 1605.3873814053727
# MSE: 3245874.665170362

# %%
plt.plot(y_test_confirmed)
plt.plot(test_linear_pred)
plt.legend(['Test Data', 'Polynomial Regression Predictions'])

# %%
linear_model = LinearRegression(normalize=True, fit_intercept=False)
linear_model.fit(poly_X_train_confirmed, y_train_confirmed)
test_linear_pred = linear_model.predict(poly_X_test_confirmed)
linear_pred = linear_model.predict(poly_future_forcast)
print('MAE:', mean_absolute_error(test_linear_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_linear_pred, y_test_confirmed))
# Out:
# MAE: 1605.3873814053727
# MSE: 3245874.665170362

# %%
linear_pred = linear_pred.reshape(1,-1)[0]
linear_df = pd.DataFrame({'Date': future_forcast_dates[-10:], 'Polynomial Predicted # of Confirmed Cases Turkey': np.round(linear_pred[-10:])})
linear_df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row0_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row1_col1{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row2_col1{
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row3_col1{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row4_col1{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row5_col1{
#             background-color:  #f7593f;
#             color:  #000000;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row6_col1{
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row7_col1{
#             background-color:  #c4161c;
#             color:  #f1f1f1;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row8_col1{
#             background-color:  #9f0e14;
#             color:  #f1f1f1;
#         }#T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row9_col1{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Polynomial Predicted # of Confirmed Cases Turkey</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row0_col0" class="data row0 col0" >11/19/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row0_col1" class="data row0 col1" >424988.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row1_col0" class="data row1 col0" >11/20/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row1_col1" class="data row1 col1" >427740.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row2_col0" class="data row2 col0" >11/21/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row2_col1" class="data row2 col1" >430516.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row3_col0" class="data row3 col0" >11/22/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row3_col1" class="data row3 col1" >433315.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row4_col0" class="data row4 col0" >11/23/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row4_col1" class="data row4 col1" >436139.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row5_col0" class="data row5 col0" >11/24/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row5_col1" class="data row5 col1" >438987.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row6_col0" class="data row6 col0" >11/25/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row6_col1" class="data row6 col1" >441860.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row7_col0" class="data row7 col0" >11/26/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row7_col1" class="data row7 col1" >444757.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row8_col0" class="data row8 col0" >11/27/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row8_col1" class="data row8 col1" >447679.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row9_col0" class="data row9 col0" >11/28/2020</td>
#                         <td id="T_6e64b724_2a3b_11eb_aaa2_00059a3c7a00row9_col1" class="data row9 col1" >450625.000000</td>
#             </tr>
#     </tbody></table>

# %%
unique_countries =  list(latest_data['Country_Region'].unique())

# %%
country_confirmed_cases = []
country_death_cases = [] 
country_recovery_cases = []
country_mortality_rate = [] 

no_cases = []
for i in unique_countries:
    cases = latest_data[latest_data['Country_Region']==i]['Confirmed'].sum()
    if cases > 0:
        country_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
        
for i in no_cases:
    unique_countries.remove(i)
    
# sort countries by the number of confirmed cases
unique_countries = [k for k, v in sorted(zip(unique_countries, country_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_countries)):
    country_confirmed_cases[i] = latest_data[latest_data['Country_Region']==unique_countries[i]]['Confirmed'].sum()
    country_death_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Deaths'].sum())
    country_recovery_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Recovered'].sum())
    country_mortality_rate.append(country_death_cases[i]/country_confirmed_cases[i])

# %%
country_df = pd.DataFrame({'Country Name': unique_countries, 'Number of Confirmed Cases': country_confirmed_cases,
                          'Number of Deaths': country_death_cases, 'Number of Recoveries' : country_recovery_cases,
                          'Mortality Rate': country_mortality_rate})
# number of cases per country/region

country_df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row0_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row0_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row1_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row151_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row0_col3{
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row0_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row60_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row75_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row113_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row147_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row177_col4{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row1_col1{
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row1_col2{
#             background-color:  #f85f43;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row1_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row9_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row12_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row15_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row16_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row17_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row18_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row19_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row19_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row20_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row23_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row51_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row66_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row73_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row94_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row99_col4{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row2_col1{
#             background-color:  #f6583e;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row2_col2{
#             background-color:  #e12d26;
#             color:  #f1f1f1;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row2_col3{
#             background-color:  #e93529;
#             color:  #f1f1f1;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row2_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row5_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row8_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row10_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row16_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row24_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row54_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row63_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row84_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row129_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row157_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row173_col4{
#             background-color:  #fee5d9;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row3_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row156_col4{
#             background-color:  #fdcebb;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row3_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row9_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row58_col4{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row3_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row5_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row31_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row32_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row33_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row34_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row35_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row36_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row36_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row37_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row38_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row41_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row50_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row58_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row62_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row124_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row135_col4{
#             background-color:  #fff2ec;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row3_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row19_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row45_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row59_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row69_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row93_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row122_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row152_col4{
#             background-color:  #fee8de;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row4_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row125_col4{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row4_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row11_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row30_col4{
#             background-color:  #fedfd0;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row4_col3{
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row4_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row15_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row16_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row16_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row20_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row44_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row72_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row78_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row89_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row121_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row149_col4{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row5_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row6_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row7_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row8_col3{
#             background-color:  #fedecf;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row5_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row14_col2{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row6_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row7_col1,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row37_col4,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row143_col4{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row6_col2{
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row6_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row17_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row22_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row37_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row38_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row41_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row42_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row43_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row45_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row56_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row57_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row59_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row61_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row62_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row62_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row64_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row65_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row67_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row68_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row70_col2,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row73_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row74_col3,#T_4c5bfbee_2a3c_11eb_9cde_00059a3c7a00row79_col2,#T_4
